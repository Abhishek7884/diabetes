# %%
import os
os.chdir("C:/Users/Dell/Desktop/data set")

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
data1=pd.read_csv('diabetes.csv')

# %%
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
data1=data1.drop(['Insulin'],axis=1)

# %%
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 0              6      148             72             35  33.6
# 1              1       85             66             29  26.6
# 2              8      183             64              0  23.3
# 3              1       89             66             23  28.1
# 4              0      137             40             35  43.1
# 5              5      116             74              0  25.6
# 6              3       78             50             32  31.0
# 7             10      115              0              0  35.3
# 8              2      197             70             45  30.5
# 9              8      125             96              0   0.0
# 10             4      110             92              0  37.6
# 11            10      168             74              0  38.0
# 12            10      139             80              0  27.1
# 13             1      189             60             23  30.1
# ...

# %%
#Examine the target variable ‘diagnosis’ which is the variable to predict
#Get a count of diagnosis observations by type
data1.Diabetes.value_counts()
# Out:
# neg    500
# pos    268
# Name: Diabetes, dtype: int64

# %%
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 0              6      148             72             35  33.6
# 1              1       85             66             29  26.6
# 2              8      183             64              0  23.3
# 3              1       89             66             23  28.1
# 4              0      137             40             35  43.1
# 5              5      116             74              0  25.6
# 6              3       78             50             32  31.0
# 7             10      115              0              0  35.3
# 8              2      197             70             45  30.5
# 9              8      125             96              0   0.0
# 10             4      110             92              0  37.6
# 11            10      168             74              0  38.0
# 12            10      139             80              0  27.1
# 13             1      189             60             23  30.1
# ...

# %%
#Get summary of parameters
x=data1.loc[:, ['BloodPressure','DiabetesPedigreeFunction','SkinThickness']]#list slishing method

# %%
x.describe()
# Out:
#        BloodPressure  DiabetesPedigreeFunction  SkinThickness
# count     768.000000                768.000000     768.000000
# mean       69.105469                  0.471876      20.536458
# std        19.355807                  0.331329      15.952218
# min         0.000000                  0.078000       0.000000
# 25%        62.000000                  0.243750       0.000000
# 50%        72.000000                  0.372500      23.000000
# 75%        80.000000                  0.626250      32.000000
# max       122.000000                  2.420000      99.000000

# %%
x=data1.iloc[:,1:31]
y=data1.iloc[:,7]

# %%
x
# Out:
#      Glucose  BloodPressure  SkinThickness   BMI  DiabetesPedigreeFunction  \
# 0        148             72             35  33.6                     0.627
# 1         85             66             29  26.6                     0.351
# 2        183             64              0  23.3                     0.672
# 3         89             66             23  28.1                     0.167
# 4        137             40             35  43.1                     2.288
# 5        116             74              0  25.6                     0.201
# 6         78             50             32  31.0                     0.248
# 7        115              0              0  35.3                     0.134
# 8        197             70             45  30.5                     0.158
# 9        125             96              0   0.0                     0.232
# 10       110             92              0  37.6                     0.191
# ...

# %%
y
# Out:
# 0      pos
# 1      neg
# 2      pos
# 3      neg
# 4      pos
# 5      neg
# 6      pos
# 7      neg
# 8      pos
# 9      pos
# 10     neg
# 11     pos
# 12     neg
# 13     pos
# 14     pos
# 15     pos
# 16     pos
# 17     pos
# 18     neg
# 19     pos
# 20     neg
# 21     neg
# 22     pos
# 23     pos
# 24     pos
# 25     pos
# 26     pos
# 27     neg
# 28     neg
# 29     neg
#       ...
# 738    neg
# 739    pos
# 740    pos
# 741    neg
# 742    neg
# 743    pos
# 744    neg
# 745    neg
# 746    pos
# 747    neg
# 748    pos
# 749    pos
# 750    pos
# 751    neg
# 752    neg
# 753    pos
# 754    pos
# 755    pos
# 756    neg
# 757    pos
# 758    neg
# 759    pos
# 760    neg
# 761    pos
# 762    neg
# 763    neg
# 764    neg
# 765    neg
# 766    pos
# 767    neg
# Name: Diabetes, Length: 768, dtype: object

# %%
data1['Diabetes'].replace(['pos','neg'],[1,0],inplace=True)

# %%
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 0              6      148             72             35  33.6
# 1              1       85             66             29  26.6
# 2              8      183             64              0  23.3
# 3              1       89             66             23  28.1
# 4              0      137             40             35  43.1
# 5              5      116             74              0  25.6
# 6              3       78             50             32  31.0
# 7             10      115              0              0  35.3
# 8              2      197             70             45  30.5
# 9              8      125             96              0   0.0
# 10             4      110             92              0  37.6
# 11            10      168             74              0  38.0
# 12            10      139             80              0  27.1
# 13             1      189             60             23  30.1
# ...

# %%
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(x).transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-137a6efd17c1> in <module>
#       1 minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
# ----> 2 minmax.fit(x).transform(x)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     321         # Reset internal state before fitting
#     322         self._reset()
# --> 323         return self.partial_fit(X, y)
#     324
#     325     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     349         X = check_array(X, copy=self.copy, warn_on_dtype=True,
#     350                         estimator=self, dtype=FLOAT_DTYPES,
# --> 351                         force_all_finite="allow-nan")
#     352
#     353         data_min = np.nanmin(X, axis=0)
#
# ...

# %%
x['BloodPressure'].describe()
# Out:
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
#Splitting the dataset into Training set and Test set
from sklearn import model_selection, neighbors
from sklearn. model_selection import train_test_split
x_train, x_test,y_train , y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      Glucose  BloodPressure  SkinThickness   BMI  DiabetesPedigreeFunction  \
# 210       81             60             22  27.7                     0.290
# 228      197             70             39  36.7                     2.329
# 479      132             86             31  28.0                     0.419
# 424      151             78             32  42.9                     0.516
# 435      141              0              0  42.4                     0.205
# 691      158            114              0  42.3                     0.257
# 611      174             58             22  32.9                     0.593
# 651      117             60             23  33.8                     0.466
# 110      171             72             33  33.3                     0.199
# 275      100             70             52  40.5                     0.677
# 97        71             48             18  20.4                     0.323
# ...

# %%
x_train = x_train.astype('int')
x_train
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-477e422ecfd4> in <module>
# ----> 1 x_train = x_train.astype('int')
#       2 x_train
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
x_test

# %%
#Build a Logistic Regression Model
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(x_train,y_train)
lr_acc = cross_val_score(lr, x_train_std, y_train, cv=3, scoring='accuracy', n_jobs=-1)
lr_proba = cross_val_predict(lr, x_train_std, y_train, cv=3, method='predict_proba')
lr_scores = lr_proba[:, 1]
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-5adbc60c89c2> in <module>
#       3
#       4 lr = LogisticRegression()
# ----> 5 lr.fit(x_train,y_train)
#       6 lr_acc = cross_val_score(lr, x_train_std, y_train, cv=3, scoring='accuracy', n_jobs=-1)
#       7 lr_proba = cross_val_predict(lr, x_train_std, y_train, cv=3, method='predict_proba')
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1283
#    1284         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1285                          accept_large_sparse=solver != 'liblinear')
# ...
